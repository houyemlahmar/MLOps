# %% [markdown]
# # 02_feature_engineering

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Clear cached modules
import importlib
import src.data
importlib.reload(src.data)
# Out:
# <module 'src.data' from 'C:\\Users\\MSI\\mlops-project\\src\\data.py'>

# %%
from src.data import load_processed

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\MSI\\mlops-project\\notebooks'

# %%
import src.data
print(src.data.__file__)
# Out:
# C:\Users\MSI\mlops-project\src\data.py

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

import importlib
import src.data
importlib.reload(src.data)

from src.data import load_processed

# %%
import src.data
print(src.data.__file__)
# Out:
# C:\Users\MSI\mlops-project\src\data.py

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_classif

# Load preprocessed data
from src.data import load_processed

df = load_processed("../data/processed/diabetes_processed.csv")
X = df.drop("diabetes", axis=1)
y = df["diabetes"]


# Example: polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = pd.DataFrame(poly.fit_transform(X), columns=poly.get_feature_names_out(X.columns))

# Feature selection
selector = SelectKBest(score_func=f_classif, k=10)
X_selected = selector.fit_transform(X_poly, y)
selected_features = X_poly.columns[selector.get_support()]

print("Selected features:", selected_features)
# Out:
# Selected features: Index(['age', 'HbA1c_level', 'blood_glucose_level', 'age bmi',
#        'age HbA1c_level', 'age blood_glucose_level',
#        'hypertension blood_glucose_level', 'bmi HbA1c_level',
#        'bmi blood_glucose_level', 'HbA1c_level blood_glucose_level'],
#       dtype='object')

# %%
selected_features = list(selected_features)  # as printed
import json
with open("../src/selected_features.json", "w") as f:
    json.dump(selected_features, f)
