# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Requirement already satisfied: click in c:\users\msi\anaconda3\lib\site-packages (from opendatasets) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\msi\anaconda3\lib\site-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: colorama in c:\users\msi\anaconda3\lib\site-packages (from click->opendatasets) (0.4.4)
# Requirement already satisfied: charset-normalizer in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.0.4)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.26.9)
# Requirement already satisfied: webencodings in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: protobuf in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (3.19.1)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (61.2.0)
# Requirement already satisfied: requests in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: six>=1.10 in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: bleach in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: text-unidecode in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: idna in c:\users\msi\anaconda3\lib\site-packages (from kaggle->opendatasets) (3.3)
# Requirement already satisfied: packaging in c:\users\msi\anaconda3\lib\site-packages (from bleach->kaggle->opendatasets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\msi\anaconda3\lib\site-packages (from packaging->bleach->kaggle->opendatasets) (3.0.4)
# Installing collected packages: kaggle, opendatasets
# Successfully installed kaggle-1.7.4.5 opendatasets-0.1.22

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: houyemlahmar
# Your Kaggle Key: ········
# Dataset URL: https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset
# Downloading diabetes-prediction-dataset.zip to .\diabetes-prediction-dataset
# 100%|██████████| 734k/734k [00:00<00:00, 256MB/s]

# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
# Requirement already satisfied: tqdm in c:\users\msi\anaconda3\lib\site-packages (from umap-learn) (4.64.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Requirement already satisfied: numba>=0.51.2 in c:\users\msi\anaconda3\lib\site-packages (from umap-learn) (0.55.1)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\msi\anaconda3\lib\site-packages (from umap-learn) (1.7.3)
# Collecting scikit-learn>=1.6
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Collecting numpy>=1.23
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Collecting numba>=0.51.2
#   Downloading numba-0.60.0-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-win_amd64.whl (28.1 MB)
# Requirement already satisfied: joblib>=0.11 in c:\users\msi\anaconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Collecting scipy>=1.3.1
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Requirement already satisfied: colorama in c:\users\msi\anaconda3\lib\site-packages (from tqdm->umap-learn) (0.4.4)
# Installing collected packages: numpy, threadpoolctl, scipy, llvmlite, joblib, scikit-learn, numba, pynndescent, umap-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.38.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import seaborn as sns
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:22, in <module>
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~\anaconda3\lib\site-packages\pandas\compat\__init__.py:15, in <module>
#      12 import sys
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_version_under1p19,
#      18     np_version_under1p20,
#      19 )
#      20 from pandas.compat.pyarrow import (
#      21     pa_version_under1p01,
#      22     pa_version_under2p0,
#      23     pa_version_under3p0,
#      24     pa_version_under4p0,
#      25 )
#      27 PY39 = sys.version_info >= (3, 9)
#
# File ~\anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py:4, in <module>
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~\anaconda3\lib\site-packages\pandas\util\__init__.py:1, in <module>
# ----> 1 from pandas.util._decorators import (  # noqa:F401
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa:F401
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:14, in <module>
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa:F401
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# read data 
df = pd.read_csv('diabetes.csv')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # read data
# ----> 2 df = pd.read_csv('diabetes.csv')
#       3 df.head(10)
#
# NameError: name 'pd' is not defined
